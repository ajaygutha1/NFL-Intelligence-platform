# %%
import nflreadpy as nfl
import polars as pl

pl.Config.set_fmt_str_lengths(200)
# Out:
# polars.config.Config

# %%
pbp = nfl.load_pbp(2023)

print(f"Total plays loaded: {pbp.height}")
# Out:
# Total plays loaded: 49665

# %%
game = pbp.filter(
    pl.col("game_id") == "2023_01_ARI_WAS"
)

print(f"Plays in this game: {game.height}")
# Out:
# Plays in this game: 175
